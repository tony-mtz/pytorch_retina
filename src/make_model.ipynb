# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import sys
import random

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage import feature

from skimage.filters import sobel
from skimage.morphology import watershed

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as dsets
from torch.autograd import Variable

from torchvision import transforms as tf

import h5py

from pathlib import Path
import nibabel as nib
# from sklearn import preprocessing
from skimage import transform

# from tqdm import tqdm

# from imgaug import augmenters as iaaot as plt
import pandas as pd

# %%
import sys
sys.path.insert(0, '../networks/')
from Att_Net import *
# from help_functions import *

# #function to obtain data for training/testing (validation)
# from extract_patches import get_data_training
# sys.path.insert(0, '../lib/networks/')

from preprocessing import preprocessing

# %%
train_img, label_img = preprocessing()
# Out:
# train images/masks shape:
# (20, 1, 565, 565)
# train images range (min-max): 0.0 - 1.0
# train masks are within 0-1
#
# patches per full image: 9500
#
# train PATCHES images/masks shape:
# (190000, 1, 48, 48)
# train PATCHES images range (min-max): 0.00784313725490196 - 1.0
# (190000, 1, 48, 48)
# 48 48 1
# ......DONE......
# masks shape:  (190000, 2304)

# %%
train_img.shape, label_img.shape
# Out:
# ((190000, 1, 48, 48), (190000, 2304))

# %%
N_subimgs = 190000
indices = list(range(N_subimgs))
# np.random.shuffle(indices)

val_size = 1/10
split = np.int_(np.floor(val_size * N_subimgs))

train_idxs = indices[split:]
val_idxs = indices[:split]

# %%
class eye_dataset(torch.utils.data.Dataset):

    def __init__(self,preprocessed_images, train=True, label=None):
        """
        Args:
            text_file(string): path to text file
            root_dir(string): directory with all train images
        """
        self.train = train
        self.images = preprocessed_images
        if self.train:
            self.label = label

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        img = np.zeros_like(image, dtype=np.float32)
        
        img += image
        label = None
        if self.train:
            label = self.label[idx]
#             msk = np.zeros((2,48,48), dtype=np.long)
#             msk[1] = label
#             msk[0] = 1-label
            
#             msk += label
            return (img, label)
        return img

eye_dataset_train = eye_dataset(train_img[train_idxs], 
                                      train=True, 
                                      label=label_img[train_idxs])

eye_dataset_val = eye_dataset(train_img[val_idxs], 
                                      train=True, 
                                      label=label_img[val_idxs])


batch_size = 64

train_loader = torch.utils.data.DataLoader(dataset=eye_dataset_train, 
                                           batch_size=batch_size, 
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=eye_dataset_val, 
                                           batch_size=batch_size, 
                                           shuffle=True)

# %%
model = Model_B_E(32)
model.cuda()
# criterion = nn.BCEWithLogitsLoss()
criterion = nn.CrossEntropyLoss()
learning_rate = 0.001

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, eps=.1,
                             weight_decay=.000001)

scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer=optimizer, 
                                                 milestones=[400,800,900], gamma=0.1)

# %%
model
# Out:
# Model_B_E(
#   (input_conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (block_1): Block_B(
#     (top_bn_relu): Sequential(
#       (0): BatchNorm2d(32, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (1): ReLU6(inplace)
#     )
#     (projection): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (residual): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (block_2): Block_B(
#     (top_bn_relu): Sequential(
#       (0): BatchNorm2d(32, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (1): ReLU6(inplace)
#     )
#     (projection): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#     )
#     (residual): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (block_3): Block_B(
#     (top_bn_relu): Sequential(
#       (0): BatchNorm2d(64, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (1): ReLU6(inplace)
#     )
#     (projection): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#     )
#     (residual): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace)
#       (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (bottom): Sequential(
#     (0): Sequential(
#       (0): BatchNorm2d(128, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (1): ReLU6(inplace)
#     )
#     (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (block4): Block_E(
#     (deconv1): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn_relu): Sequential(
#       (0): BatchNorm2d(64, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (1): ReLU6(inplace)
#     )
#     (res_): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (block5): Block_E(
#     (deconv1): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn_relu): Sequential(
#       (0): BatchNorm2d(32, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (1): ReLU6(inplace)
#     )
#     (res_): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (out): Sequential(
#     (0): Sequential(
#       (0): BatchNorm2d(32, eps=1e-05, momentum=0.997, affine=True, track_running_stats=True)
#       (1): ReLU6(inplace)
#     )
#     (1): Dropout2d(p=0.5)
#     (2): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
# learning_rate = 0.0001
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, eps=.1,
#                              weight_decay=.01)

# %%
def accuracy(out, labels):
    total = 0.0
    predicted = torch.exp(out)
    size = predicted.shape[0]*predicted.shape[2]
    pred = torch.argmax(predicted.data, dim=1)
    total += torch.sum(pred == labels.data)
    return total.cpu().detach().numpy()/size

# %%
path = 'expr/b_e/expr1/'

mean_train_losses = []
mean_val_losses = []

mean_train_acc = []
mean_val_acc = []
minLoss = 99999
maxValacc = -99999
for epoch in range(1000):
    scheduler.step()
    print('EPOCH: ',epoch+1)
#     train_losses = []
#     val_losses = []    
    train_acc = []
    val_acc = []
    
    running_loss = 0.0
    
    model.train()
    count = 0
    for images, labels in train_loader:    
#         labels = labels.squeeze()
        images = Variable(images.cuda())
        labels = labels.type(torch.LongTensor)
        labels = Variable(labels.cuda())
        
        outputs = model(images) 
        
        optimizer.zero_grad()
        loss = criterion(outputs, labels)
        
        train_acc.append(accuracy(outputs, labels))
        
        loss.backward()
        optimizer.step()        
        
        running_loss += loss.item()
        count +=1
    
    print('Training loss:.......', running_loss/count)
#     print('Training accuracy:...', np.mean(train_acc))
    mean_train_losses.append(running_loss/count)
        
    model.eval()
    count = 0
    val_running_loss = 0.0
    for images, labels in val_loader:
#         labels = labels.squeeze()
        images = Variable(images.cuda())
        labels = labels.type(torch.LongTensor)
        labels = Variable(labels.cuda())
                
        outputs = model(images)
        loss = criterion(outputs, labels)

        val_acc.append(accuracy(outputs, labels))
        val_running_loss += loss.item()
        count +=1

    mean_val_loss = val_running_loss/count
    print('Validation loss:.....', mean_val_loss)
    print('')    
    print('Training accuracy:...', np.mean(train_acc))
    print('Validation accuracy..', np.mean(val_acc))
    
    mean_val_losses.append(mean_val_loss)
    
    mean_train_acc.append(np.mean(train_acc))
    
    val_acc_ = np.mean(val_acc)
    mean_val_acc.append(val_acc_)
    
   
    if mean_val_loss < minLoss:
        torch.save(model.state_dict(), path+'best_val_loss.pth' )
        print(f'NEW BEST Loss: {mean_val_loss} ........old best:{minLoss}')
        minLoss = mean_val_loss
        print('')
    
    if (epoch+1)%100 ==0:
        torch.save(model.state_dict(), path+'epoch_'+str(epoch+1)+'.pth')
        
        
    if val_acc_ > maxValacc:
        torch.save(model.state_dict(), path+'best_acc.pth' )
        print(f'NEW BEST Acc: {val_acc_} ........old best:{maxValacc}')
        maxValacc = val_acc_
    
    
    print('')
# Out:
# EPOCH:  1
# Training loss:....... 0.28681784369676055
# Validation loss:..... 0.14764713583771227
#
# Training accuracy:... 0.8881203515732904
# Validation accuracy.. 0.946754457605152
# NEW BEST Loss: 0.14764713583771227 ........old best:99999
#
# NEW BEST Acc: 0.946754457605152 ........old best:-99999
#
# EPOCH:  2
# Training loss:....... 0.17437044643757943
# Validation loss:..... 0.13170235563909968
#
# Training accuracy:... 0.9344177253345336
# Validation accuracy.. 0.9501431271315168
# NEW BEST Loss: 0.13170235563909968 ........old best:0.14764713583771227
#
# NEW BEST Acc: 0.9501431271315168 ........old best:0.946754457605152
#
# EPOCH:  3
# Training loss:....... 0.1614928948218951
# Validation loss:..... 0.12441993871020147
#
# Training accuracy:... 0.9388780727119977
# Validation accuracy.. 0.9526138587010984
# NEW BEST Loss: 0.12441993871020147 ........old best:0.13170235563909968
#
# NEW BEST Acc: 0.9526138587010984 ........old best:0.9501431271315168
#
# EPOCH:  4
# Training loss:....... 0.154135834113388
# Validation loss:..... 0.11998583459191853
#
# Training accuracy:... 0.9414698663585914
# Validation accuracy.. 0.9534642962309521
# NEW BEST Loss: 0.11998583459191853 ........old best:0.12441993871020147
#
# NEW BEST Acc: 0.9534642962309521 ........old best:0.9526138587010984
#
# EPOCH:  5
# Training loss:....... 0.14936972942905957
# Validation loss:..... 0.1318261387823808
#
# Training accuracy:... 0.9430259169422734
# Validation accuracy.. 0.9493517838719119
#
# EPOCH:  6
# Training loss:....... 0.14565198151617795
# Validation loss:..... 0.11368150401998449
#
# Training accuracy:... 0.9443351681066344
# Validation accuracy.. 0.9554975031659603
# NEW BEST Loss: 0.11368150401998449 ........old best:0.11998583459191853
#
# NEW BEST Acc: 0.9554975031659603 ........old best:0.9534642962309521
#
# EPOCH:  7
# Training loss:....... 0.14282051676850832
# Validation loss:..... 0.11586141006814109
#
# Training accuracy:... 0.945384983598999
# Validation accuracy.. 0.9556566199361338
# NEW BEST Acc: 0.9556566199361338 ........old best:0.9554975031659603
#
# EPOCH:  8
# Training loss:....... 0.14049657620768435
# Validation loss:..... 0.11070282363430017
#
# Training accuracy:... 0.9462377132883136
# Validation accuracy.. 0.9566002330420189
# NEW BEST Loss: 0.11070282363430017 ........old best:0.11368150401998449
#
# NEW BEST Acc: 0.9566002330420189 ........old best:0.9556566199361338
#
# EPOCH:  9
# Training loss:....... 0.13829006002323624
# Validation loss:..... 0.10889548820879323
#
# Training accuracy:... 0.9469789733973738
# Validation accuracy.. 0.9571410845757092
# NEW BEST Loss: 0.10889548820879323 ........old best:0.11070282363430017
#
# NEW BEST Acc: 0.9571410845757092 ........old best:0.9566002330420189
#
# EPOCH:  10
# Training loss:....... 0.1367295643141839
# Validation loss:..... 0.11109371453222602
#
# Training accuracy:... 0.9475141981574657
# Validation accuracy.. 0.9568231609247233
#
# EPOCH:  11
# Training loss:....... 0.13519759196788073
# Validation loss:..... 0.11109636159557285
#
# Training accuracy:... 0.9479723664678873
# Validation accuracy.. 0.9568145329524994
#
# EPOCH:  12
# Training loss:....... 0.13379905660062313
# Validation loss:..... 0.10836403591163231
#
# Training accuracy:... 0.9484207096032775
# Validation accuracy.. 0.9568990283644145
# NEW BEST Loss: 0.10836403591163231 ........old best:0.10889548820879323
#
#
# EPOCH:  13
# Training loss:....... 0.13245420305694114
# Validation loss:..... 0.11252139624120411
#
# Training accuracy:... 0.948898487292296
# Validation accuracy.. 0.9565011434721721
#
# EPOCH:  14
# Training loss:....... 0.13122253015938545
# Validation loss:..... 0.10682450285062244
#
# Training accuracy:... 0.9492902147510458
# Validation accuracy.. 0.9576874195201018
# NEW BEST Loss: 0.10682450285062244 ........old best:0.10836403591163231
#
# NEW BEST Acc: 0.9576874195201018 ........old best:0.9571410845757092
#
# EPOCH:  15
# Training loss:....... 0.13025958911365199
# Validation loss:..... 0.10635346262041567
#
# Training accuracy:... 0.9495730150358926
# Validation accuracy.. 0.9579390953495772
# NEW BEST Loss: 0.10635346262041567 ........old best:0.10682450285062244
#
# NEW BEST Acc: 0.9579390953495772 ........old best:0.9576874195201018
#
# EPOCH:  16
# Training loss:....... 0.12907658262222915
# Validation loss:..... 0.11430926460409004
#
# Training accuracy:... 0.9499866281463534
# Validation accuracy.. 0.9557611896546899
#
# EPOCH:  17
# Training loss:....... 0.12822714123127613
# Validation loss:..... 0.10664210619047435
#
# Training accuracy:... 0.9502397752422286
# Validation accuracy.. 0.9580761610451823
# NEW BEST Acc: 0.9580761610451823 ........old best:0.9579390953495772
#
# EPOCH:  18
# Training loss:....... 0.1274237089043115
# Validation loss:..... 0.10586405595645358
#
# Training accuracy:... 0.9504852041116335
# Validation accuracy.. 0.9582552738341583
# NEW BEST Loss: 0.10586405595645358 ........old best:0.10635346262041567
#
# NEW BEST Acc: 0.9582552738341583 ........old best:0.9580761610451823
#
# EPOCH:  19
# Training loss:....... 0.1265119182302834
# Validation loss:..... 0.10790211707353592
#
# Training accuracy:... 0.9507840648484699
# Validation accuracy.. 0.9576846827077405
#
# EPOCH:  20
# Training loss:....... 0.12560926054598776
# Validation loss:..... 0.10568089918656783
#
# Training accuracy:... 0.9510609075921352
# Validation accuracy.. 0.9582407840600113
# NEW BEST Loss: 0.10568089918656783 ........old best:0.10586405595645358
#
#
# EPOCH:  21
# Training loss:....... 0.1248986839991576
# Validation loss:..... 0.10823125888903935
#
# Training accuracy:... 0.9512628856782575
# Validation accuracy.. 0.9575358412163969
#
# EPOCH:  22
# Training loss:....... 0.12406051767610772
# Validation loss:..... 0.11054379217050693
#
# Training accuracy:... 0.9515382657768542
# Validation accuracy.. 0.956675069691834
#
# EPOCH:  23
# Training loss:....... 0.12344766758148096
# Validation loss:..... 0.10572921642751405
#
# Training accuracy:... 0.9517254473625757
# Validation accuracy.. 0.9583432661028691
# NEW BEST Acc: 0.9583432661028691 ........old best:0.9582552738341583
#
# EPOCH:  24
# Training loss:....... 0.12263163528823388
# Validation loss:..... 0.10935470476897076
#
# Training accuracy:... 0.9519338322256854
# Validation accuracy.. 0.9570809073236919
#
# EPOCH:  25
# Training loss:....... 0.12196861896775439
# Validation loss:..... 0.10535011375291581
#
# Training accuracy:... 0.9521822103154647
# Validation accuracy.. 0.9583854273660047
# NEW BEST Loss: 0.10535011375291581 ........old best:0.10568089918656783
#
# NEW BEST Acc: 0.9583854273660047 ........old best:0.9583432661028691
#
# EPOCH:  26
# Training loss:....... 0.12143412104411842
# Validation loss:..... 0.10791372728568537
#
# Training accuracy:... 0.9522909108772782
# Validation accuracy.. 0.9575396903684664
#
# EPOCH:  27
# Training loss:....... 0.12078220440732862
# Validation loss:..... 0.10561487906508976
#
# Training accuracy:... 0.952467728132486
# Validation accuracy.. 0.9583073319849035
#
# EPOCH:  28
# Training loss:....... 0.12010580194768256
# Validation loss:..... 0.10745740940273811
#
# Training accuracy:... 0.9527179499382235
# Validation accuracy.. 0.9575213188223172
#
# EPOCH:  29
# Training loss:....... 0.11945706069145999
# Validation loss:..... 0.10752437233623832
#
# Training accuracy:... 0.9529126365537619
# Validation accuracy.. 0.9577149507433794
#
# EPOCH:  30
# Training loss:....... 0.11887827641637383
# Validation loss:..... 0.10669461391891294
#
# Training accuracy:... 0.9530676917968148
# Validation accuracy.. 0.9579401457114132
#
# EPOCH:  31
# Training loss:....... 0.1183053852187213
# Validation loss:..... 0.10752381331691838
#
# Training accuracy:... 0.9532438908542429
# Validation accuracy.. 0.9576029143222069
#
# EPOCH:  32
# Training loss:....... 0.11773861212443984
# Validation loss:..... 0.11231224464647697
#
# Training accuracy:... 0.9533533825641824
# Validation accuracy.. 0.956052211647101
#
# EPOCH:  33
# Training loss:....... 0.1171584780729504
# Validation loss:..... 0.10883337916549207
#
# Training accuracy:... 0.9536011660238396
# Validation accuracy.. 0.9573342239357864
#
# EPOCH:  34
# Training loss:....... 0.1166079177320405
# Validation loss:..... 0.10783401992084202
#
# Training accuracy:... 0.9536800038258212
# Validation accuracy.. 0.9575919050948892
#
# EPOCH:  35
# Training loss:....... 0.11613366941915836
# Validation loss:..... 0.1165343416911183
#
# Training accuracy:... 0.9538580255696059
# Validation accuracy.. 0.9546591774171526
#
# EPOCH:  36
